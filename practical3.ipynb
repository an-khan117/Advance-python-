# %%
! pip install  numpy
! pip install pandas
! pip install scipy
import numpy as np 
import pandas as pd


from scipy.constants import pi
from math import pi
print('Pi=',pi)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Pi= 3.141592653589793

# %%
from scipy.fftpack import fft
x=np.array([1,2,3,4,5])
y=fft(x)
print(y)

from scipy.fftpack import dct
print(dct(np.array([1,2,3,4,5])))

import numpy as np
from scipy import interpolate
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
x=np.linspace(0,4,12)
y=np.cos(x**2/3+4)
print(x)
print(y)
f1=interp1d(x,y,kind='linear')
f2=interp1d(x,y,kind='cubic')
xnew=np.linspace(0,4,30)
plt.plot(x,y,'o',xnew,f1(xnew),'-',xnew,f2(xnew))
plt.legend(['data','linear','cubic','nearest'],loc='best')
plt.show()
# Out:
# [15. -0.j         -2.5+3.4409548j  -2.5+0.81229924j -2.5-0.81229924j
#  -2.5-3.4409548j ]
# [ 3.00000000e+01 -9.95959314e+00  1.11022302e-16 -8.98055953e-01
#   8.88178420e-16]
# [0.         0.36363636 0.72727273 1.09090909 1.45454545 1.81818182
#  2.18181818 2.54545455 2.90909091 3.27272727 3.63636364 4.        ]
# [-0.65364362 -0.61966189 -0.51077021 -0.31047698 -0.00715476  0.37976236
#   0.76715099  0.99239518  0.85886263  0.27994201 -0.52586509 -0.99582185]

# %%
import numpy as np
from scipy import stats
data = [10, 20, 30, 40]
median_value = stats.tmedian(data)
 
print("Mean:", mean_value)

median_value = stats.tmedian(data)
print("Median:", median_value)


mode_value = stats.mode([10, 20, 20, 30])
print("Mode:", mode_value)


variance_value = stats.tvar(data)
print("Variance:", variance_value)


stdev_value = stats.tstd(data)
print("Standard Deviation:", stdev_value)


from scipy.stats import norm
prob = norm.pdf(0)   
print("Probability at 0:", prob)


data1 = [10, 20, 30]
data2 = [15, 25, 35]
t_stat, p_val = stats.ttest_ind(data1, data2)
print("t-statistic:", t_stat)
print("p-value:", p_val)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 4
#       2 from scipy import stats
#       3 data = [10, 20, 30, 40]
# ----> 4 median_value = stats.tmedian(data)
#       6 print("Mean:", mean_value)
#       8 median_value = stats.tmedian(data)
#
# AttributeError: module 'scipy.stats' has no attribute 'tmedian'

# %%
# !pip install pooch

from scipy.datasets import face
import matplotlib.pyplot as plt

f = face()   

plt.imsave('Anni.jpg', f)
plt.imshow(f)
plt.axis('off')
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
crop_face = f[f.shape[0]//4 : -f.shape[0]//4,f.shape[1]//4 : -f.shape[1]//4]
plt.imshow(crop_face)
plt.show()

from scipy.datasets import face
import matplotlib.pyplot as plt
import numpy as np

img = face()  
flipface = np.flipud(img)  
plt.imshow(flipface)
plt.axis('off')
plt.show()


from scipy.datasets import face
from scipy import ndimage
import matplotlib.pyplot as plt

face_img = face()

rface = ndimage.rotate(face_img, 45, reshape=True)

plt.imshow(rface)
plt.axis('off')
plt.show()

bface = ndimage.gaussian_filter(f, sigma=3)
plt.imshow(bface)
plt.axis('off')
plt.show()

# %%
im = np.zeros((256,256))
im[64: -64, 64: -64] =1
im[90:-90 , 90: -90] =2
im=ndimage.gaussian_filter(im,8)
plt.imshow(im)
plt.show()


Sx= ndimage.sobel(im,axis=0,mode='constant')
Sy= ndimage.sobel(im,axis=1,mode='constant')
sob=np.hypot(Sx,Sy)
plt.imshow(sob)
plt.show()
